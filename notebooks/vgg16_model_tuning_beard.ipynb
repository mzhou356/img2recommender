# %% [markdown]
# ## Transfer Learning Tuning_beard:
#   * model parameter and other information can be found below:
#      * [source](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)
#
#   * base_model: use vgg16 and freeze at bottleneck layer (stop right before flatten layer)
#   * top_model: tune dense layers (parameters are inspired by source)
#      * batch_size 16 seems to work best for small data set
#
#   * extra blog source for callbacks and saving models:
#
#   [call_backs for best weights](https://machinelearningmastery.com/check-point-deep-learning-models-keras/)
#
#   [saving models](https://machinelearningmastery.com/save-load-keras-deep-learning-models/)
#
# ##### warnings: has beard: 0 and no beard: 1
# ---
# #### This cell is required in order to use GPU for running the model

# %%
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import keras
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
                                    # (nothing gets printed in Jupyter, only if you run it standalone)
sess = tf.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras
keras.backend.get_session().run(tf.global_variables_initializer())
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0831 21:25:52.645286 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0831 21:25:52.646269 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# ---
# #### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from keras_preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense
from keras.applications.vgg16 import VGG16
from keras import optimizers
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ---
# #### Import train_df and test_df

# %%
train_df = pd.read_pickle('../pickle_files/train_df_beard.pkl')
test_df = pd.read_pickle('../pickle_files/test_df_beard.pkl')

# %%
train_df.head(2)
# Out:
#         pic_id      beard
# 119  00725.jpg      beard
# 423  00513.jpg  not_beard

# %% [markdown]
# #### Get bottleneck features to tune top models

# %%
def save_bottleneck_features(train_df, test_df, label, batch_size):
    '''
    inputs:
    train_df, test_df: train and test dataframes saved in pickle_files folder
    label: a string, eyewear, hat, or beard
    batch_size: process images in batches
    outputs:
    saves bottleneck features inside folder tuning_data as npy file
    '''
    # intialize the vgg16 model 
    # make sure not to train the top layers 
    base_model = VGG16(weights = 'imagenet', include_top = False)
    # create train_generator and test_generator to get bottleneck inputs for train and test df 
    datagen = ImageDataGenerator(
        rescale=1./255,
        zoom_range= [0.8,1.7],
        shear_range=0.2,
        rotation_range = 40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True)
    # make sure shuffle is False so we know the label follows the sequence of the dataframe 
    # so we can tune top_model 
    train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='../data/pics',
    x_col='pic_id',
    y_col=label,
    batch_size=batch_size,
    shuffle = False,
    target_size=(150,150),
    class_mode = None)
    # get features saved as .npy in tunign_data folder 
    bottleneck_features_train = base_model.predict_generator(
        train_generator, train_df.shape[0]//batch_size)
    np.save(open('../tuning_data/bottleneck_features_train_beard_2.npy','wb'),
           bottleneck_features_train)
    
    test_generator = datagen.flow_from_dataframe(
    dataframe=test_df,
    directory='../data/pics',
    x_col='pic_id',
    y_col=label,
    batch_size=batch_size,
    shuffle = False,
    target_size=(150,150),
    class_mode = None)
    bottleneck_features_test = base_model.predict_generator(
        test_generator, test_df.shape[0]//batch_size)
    np.save(open('../tuning_data/bottleneck_features_test_beard_2.npy','wb'),
           bottleneck_features_test)

# %% [markdown]
# #### Save bottleneck_features

# %%
save_bottleneck_features(train_df,test_df,'beard',16)
# Out:
# W0829 22:58:34.993765 140622077245248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0829 22:58:34.994647 140622077245248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0829 22:58:34.996672 140622077245248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0829 22:58:35.013768 140622077245248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Found 363 validated image filenames.
# Found 91 validated image filenames.

# %% [markdown]
# ### Quick tuning of top models

# %%
def train_top_model(train_df, test_df, epoch, batch_size, label):
    '''
    inputs:
    train_df, test_df: dataframes saved in pickle_files to generate train and test labels 
    epoch: num of epochs in fit 
    batch_size: same as image generator batch size 
    label: a string, eyewear, hat, or beard
    output:
    saves model weights in a folder 
    '''
    train_data = np.load(open('../tuning_data/bottleneck_features_train_beard_2.npy','rb'))
    # make sure train_data and train_label have same num of samples
    train_label = np.array(train_df[label].map({'not_'+label:0, label:1}))[:-(train_df.shape[0]%batch_size)]
    
    test_data = np.load(open('../tuning_data/bottleneck_features_test_beard_2.npy','rb'))
    test_label = np.array(test_df[label].map({'not_'+label:0, label:1}))[:-(test_df.shape[0]%batch_size)]
    
    # build top model
    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
    
     # checkpoint for best weights 
    filepath="../tuning_data/best_bottleneck_vgg_model_beard_2.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    model.fit(train_data, train_label,
             epochs=epoch,
             batch_size=batch_size,
             validation_data=(test_data,test_label),
             callbacks=callbacks_list)
    del model
    keras.backend.clear_session()

# %% [markdown]
# #### run train_top_model and save results in tuning_data

# %%
train_top_model(train_df, test_df, 50, 16, 'beard')
# Out:
# W0829 22:59:37.013910 140622077245248 deprecation.py:506] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0829 22:59:37.027437 140622077245248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0829 22:59:37.037425 140622077245248 deprecation.py:323] From /home/mindy/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 352 samples, validate on 80 samples
# Epoch 1/50
# 352/352 [==============================] - 0s 1ms/step - loss: 1.9358 - acc: 0.5739 - val_loss: 0.6659 - val_acc: 0.7000
#
# Epoch 00001: val_acc improved from -inf to 0.70000, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 2/50
# 352/352 [==============================] - 0s 194us/step - loss: 0.7819 - acc: 0.6733 - val_loss: 0.6043 - val_acc: 0.6625
#
# Epoch 00002: val_acc did not improve from 0.70000
# Epoch 3/50
# 352/352 [==============================] - 0s 200us/step - loss: 0.5146 - acc: 0.7841 - val_loss: 0.5723 - val_acc: 0.7125
#
# Epoch 00003: val_acc improved from 0.70000 to 0.71250, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 4/50
# 352/352 [==============================] - 0s 204us/step - loss: 0.3760 - acc: 0.8551 - val_loss: 0.4350 - val_acc: 0.8125
#
# Epoch 00004: val_acc improved from 0.71250 to 0.81250, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 5/50
# 352/352 [==============================] - 0s 196us/step - loss: 0.4700 - acc: 0.8125 - val_loss: 0.7226 - val_acc: 0.6750
#
# Epoch 00005: val_acc did not improve from 0.81250
# Epoch 6/50
# 352/352 [==============================] - 0s 197us/step - loss: 0.2879 - acc: 0.8722 - val_loss: 0.4109 - val_acc: 0.8250
#
# Epoch 00006: val_acc improved from 0.81250 to 0.82500, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 7/50
# 352/352 [==============================] - 0s 198us/step - loss: 0.2563 - acc: 0.8949 - val_loss: 0.4049 - val_acc: 0.8375
#
# Epoch 00007: val_acc improved from 0.82500 to 0.83750, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 8/50
# 352/352 [==============================] - 0s 198us/step - loss: 0.2961 - acc: 0.8750 - val_loss: 0.6670 - val_acc: 0.7500
#
# Epoch 00008: val_acc did not improve from 0.83750
# Epoch 9/50
# 352/352 [==============================] - 0s 196us/step - loss: 0.2094 - acc: 0.9290 - val_loss: 0.3980 - val_acc: 0.8250
#
# Epoch 00009: val_acc did not improve from 0.83750
# Epoch 10/50
# 352/352 [==============================] - 0s 197us/step - loss: 0.1893 - acc: 0.9318 - val_loss: 0.5509 - val_acc: 0.7750
#
# Epoch 00010: val_acc did not improve from 0.83750
# Epoch 11/50
# 352/352 [==============================] - 0s 198us/step - loss: 0.2710 - acc: 0.9290 - val_loss: 0.4280 - val_acc: 0.8250
#
# Epoch 00011: val_acc did not improve from 0.83750
# Epoch 12/50
# 352/352 [==============================] - 0s 190us/step - loss: 0.1270 - acc: 0.9517 - val_loss: 0.7537 - val_acc: 0.7250
#
# Epoch 00012: val_acc did not improve from 0.83750
# Epoch 13/50
# 352/352 [==============================] - 0s 189us/step - loss: 0.1269 - acc: 0.9489 - val_loss: 0.4844 - val_acc: 0.8250
#
# Epoch 00013: val_acc did not improve from 0.83750
# Epoch 14/50
# 352/352 [==============================] - 0s 194us/step - loss: 0.0711 - acc: 0.9716 - val_loss: 0.4834 - val_acc: 0.8250
#
# Epoch 00014: val_acc did not improve from 0.83750
# Epoch 15/50
# 352/352 [==============================] - 0s 193us/step - loss: 0.0531 - acc: 0.9858 - val_loss: 0.6292 - val_acc: 0.7875
#
# Epoch 00015: val_acc did not improve from 0.83750
# Epoch 16/50
# 352/352 [==============================] - 0s 191us/step - loss: 0.0332 - acc: 0.9972 - val_loss: 0.9668 - val_acc: 0.7375
#
# Epoch 00016: val_acc did not improve from 0.83750
# Epoch 17/50
# 352/352 [==============================] - 0s 205us/step - loss: 0.1478 - acc: 0.9545 - val_loss: 0.5692 - val_acc: 0.8000
#
# Epoch 00017: val_acc did not improve from 0.83750
# Epoch 18/50
# 352/352 [==============================] - 0s 187us/step - loss: 0.0262 - acc: 0.9943 - val_loss: 0.6085 - val_acc: 0.8125
#
# Epoch 00018: val_acc did not improve from 0.83750
# Epoch 19/50
# 352/352 [==============================] - 0s 188us/step - loss: 0.0272 - acc: 0.9943 - val_loss: 0.5378 - val_acc: 0.8125
#
# Epoch 00019: val_acc did not improve from 0.83750
# Epoch 20/50
# 352/352 [==============================] - 0s 191us/step - loss: 0.0108 - acc: 0.9972 - val_loss: 0.5989 - val_acc: 0.8375
#
# Epoch 00020: val_acc did not improve from 0.83750
# Epoch 21/50
# 352/352 [==============================] - 0s 192us/step - loss: 0.1156 - acc: 0.9773 - val_loss: 0.6085 - val_acc: 0.8250
#
# Epoch 00021: val_acc did not improve from 0.83750
# Epoch 22/50
# 352/352 [==============================] - 0s 190us/step - loss: 0.0118 - acc: 0.9972 - val_loss: 0.8531 - val_acc: 0.7875
#
# Epoch 00022: val_acc did not improve from 0.83750
# Epoch 23/50
# 352/352 [==============================] - 0s 189us/step - loss: 0.0317 - acc: 0.9886 - val_loss: 1.8999 - val_acc: 0.6375
#
# Epoch 00023: val_acc did not improve from 0.83750
# Epoch 24/50
# 352/352 [==============================] - 0s 197us/step - loss: 0.0323 - acc: 0.9915 - val_loss: 0.6672 - val_acc: 0.8250
#
# Epoch 00024: val_acc did not improve from 0.83750
# Epoch 25/50
# 352/352 [==============================] - 0s 194us/step - loss: 0.0579 - acc: 0.9830 - val_loss: 0.8520 - val_acc: 0.8000
#
# Epoch 00025: val_acc did not improve from 0.83750
# Epoch 26/50
# 352/352 [==============================] - 0s 195us/step - loss: 0.0129 - acc: 0.9972 - val_loss: 0.6147 - val_acc: 0.8500
#
# Epoch 00026: val_acc improved from 0.83750 to 0.85000, saving model to ../tuning_data/best_bottleneck_vgg_model_beard_2.h5
# Epoch 27/50
# 352/352 [==============================] - 0s 195us/step - loss: 0.0074 - acc: 0.9972 - val_loss: 1.1461 - val_acc: 0.7500
#
# Epoch 00027: val_acc did not improve from 0.85000
# Epoch 28/50
# 352/352 [==============================] - 0s 203us/step - loss: 0.0819 - acc: 0.9716 - val_loss: 1.1718 - val_acc: 0.7625
#
# Epoch 00028: val_acc did not improve from 0.85000
# Epoch 29/50
# 352/352 [==============================] - 0s 194us/step - loss: 0.0087 - acc: 0.9972 - val_loss: 1.0121 - val_acc: 0.7750
#
# Epoch 00029: val_acc did not improve from 0.85000
# Epoch 30/50
# 352/352 [==============================] - 0s 190us/step - loss: 0.0285 - acc: 0.9915 - val_loss: 0.7861 - val_acc: 0.8125
#
# Epoch 00030: val_acc did not improve from 0.85000
# Epoch 31/50
# 352/352 [==============================] - 0s 187us/step - loss: 0.0489 - acc: 0.9773 - val_loss: 1.0267 - val_acc: 0.8000
#
# Epoch 00031: val_acc did not improve from 0.85000
# Epoch 32/50
# 352/352 [==============================] - 0s 184us/step - loss: 0.0255 - acc: 0.9972 - val_loss: 2.1180 - val_acc: 0.7125
#
# Epoch 00032: val_acc did not improve from 0.85000
# Epoch 33/50
# 352/352 [==============================] - 0s 192us/step - loss: 0.0239 - acc: 0.9915 - val_loss: 1.3743 - val_acc: 0.7625
#
# Epoch 00033: val_acc did not improve from 0.85000
# Epoch 34/50
# 352/352 [==============================] - 0s 194us/step - loss: 0.0241 - acc: 0.9943 - val_loss: 0.8109 - val_acc: 0.7750
#
# Epoch 00034: val_acc did not improve from 0.85000
# Epoch 35/50
# 352/352 [==============================] - 0s 184us/step - loss: 0.0084 - acc: 0.9943 - val_loss: 0.8257 - val_acc: 0.8125
#
# Epoch 00035: val_acc did not improve from 0.85000
# Epoch 36/50
# 352/352 [==============================] - 0s 191us/step - loss: 0.0082 - acc: 0.9972 - val_loss: 1.0687 - val_acc: 0.7625
#
# Epoch 00036: val_acc did not improve from 0.85000
# Epoch 37/50
# 352/352 [==============================] - 0s 187us/step - loss: 0.0587 - acc: 0.9858 - val_loss: 0.8279 - val_acc: 0.8125
#
# Epoch 00037: val_acc did not improve from 0.85000
# Epoch 38/50
# 352/352 [==============================] - 0s 192us/step - loss: 4.9009e-04 - acc: 1.0000 - val_loss: 0.7294 - val_acc: 0.8125
#
# Epoch 00038: val_acc did not improve from 0.85000
# Epoch 39/50
# 352/352 [==============================] - 0s 187us/step - loss: 0.0317 - acc: 0.9858 - val_loss: 0.7542 - val_acc: 0.8125
#
# Epoch 00039: val_acc did not improve from 0.85000
# Epoch 40/50
# 352/352 [==============================] - 0s 187us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.7393 - val_acc: 0.8250
#
# Epoch 00040: val_acc did not improve from 0.85000
# Epoch 41/50
# 352/352 [==============================] - 0s 184us/step - loss: 0.0194 - acc: 0.9858 - val_loss: 1.0962 - val_acc: 0.7750
#
# Epoch 00041: val_acc did not improve from 0.85000
# Epoch 42/50
# 352/352 [==============================] - 0s 189us/step - loss: 4.0174e-04 - acc: 1.0000 - val_loss: 0.8802 - val_acc: 0.8250
#
# Epoch 00042: val_acc did not improve from 0.85000
# Epoch 43/50
# 352/352 [==============================] - 0s 192us/step - loss: 1.3376e-04 - acc: 1.0000 - val_loss: 0.9022 - val_acc: 0.8125
#
# Epoch 00043: val_acc did not improve from 0.85000
# Epoch 44/50
# 352/352 [==============================] - 0s 188us/step - loss: 0.1313 - acc: 0.9773 - val_loss: 0.8223 - val_acc: 0.8125
#
# Epoch 00044: val_acc did not improve from 0.85000
# Epoch 45/50
# 352/352 [==============================] - 0s 188us/step - loss: 2.6773e-04 - acc: 1.0000 - val_loss: 1.3104 - val_acc: 0.7875
#
# Epoch 00045: val_acc did not improve from 0.85000
# Epoch 46/50
# 352/352 [==============================] - 0s 188us/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.9321 - val_acc: 0.8250
#
# Epoch 00046: val_acc did not improve from 0.85000
# Epoch 47/50
# 352/352 [==============================] - 0s 183us/step - loss: 0.0072 - acc: 0.9943 - val_loss: 1.1527 - val_acc: 0.7875
#
# Epoch 00047: val_acc did not improve from 0.85000
# Epoch 48/50
# 352/352 [==============================] - 0s 185us/step - loss: 9.3913e-04 - acc: 1.0000 - val_loss: 1.0267 - val_acc: 0.7875
#
# Epoch 00048: val_acc did not improve from 0.85000
# Epoch 49/50
# 352/352 [==============================] - 0s 181us/step - loss: 0.0100 - acc: 0.9943 - val_loss: 0.8736 - val_acc: 0.8000
#
# Epoch 00049: val_acc did not improve from 0.85000
# Epoch 50/50
# 352/352 [==============================] - 0s 192us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.8499 - val_acc: 0.8250
#
# Epoch 00050: val_acc did not improve from 0.85000

# %% [markdown]
# ### Fine Tune Top Model to improve accuracy

# %%
def fine_tune_model(train_df, test_df,epoch, batch_size,label, print_model = True):
    # build VGG16 model and freeze top layers
    # input_shape: width, height, RGB (from image generator)
    model_vgg = VGG16(weights='imagenet',include_top=False, input_shape=(150,150,3))
    # build top model
    top_model = Sequential()
    top_model.add(Flatten(input_shape=model_vgg.output_shape[1:]))
    top_model.add(Dense(256,activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(1, activation='sigmoid'))
    
    # load saved weights to fine tune parameters 
    top_model.load_weights('../tuning_data/best_bottleneck_vgg_model_beard_2.h5')
    # add top model to model
    model = Model(inputs=model_vgg.input, outputs=top_model(model_vgg.output))
    # we will tune last 5 layers of the model: block5 and fully connected layer 
    for layer in model.layers[:15]:
        layer.trainable = False
    # we can tune the parameters for lr and momentum later to get better results
    model.compile(loss='binary_crossentropy',
             optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
             metrics=['accuracy'])
    # prepare train generator using data augmentation to battle small sample size 
    train_gen = ImageDataGenerator(
        rescale=1./255,
        zoom_range= [0.8,1.7],
        shear_range=0.2,
        rotation_range = 40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True)
    # not want to augment the test 
    test_gen = ImageDataGenerator(rescale=1./255)
    
    train_generator =  train_gen.flow_from_dataframe(
    dataframe=train_df,
    directory='../data/pics',
    x_col='pic_id',
    y_col=label,
    batch_size=batch_size,
    target_size=(150,150),
    class_mode = 'binary')
    
    test_generator =  test_gen.flow_from_dataframe(
    dataframe=test_df,
    directory='../data/pics',
    x_col='pic_id',
    y_col=label,
    batch_size=batch_size,
    target_size=(150,150),
    class_mode = 'binary')
    
    # checkpoint for best weights 
    filepath="../tuning_data/best_vgg_model_beard_2.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    # run and fit model 
    result = model.fit_generator(
    train_generator,
    steps_per_epoch=train_df.shape[0]//batch_size,
    epochs=epoch,
    validation_data=test_generator,
    validation_steps=test_df.shape[0]//batch_size,
    verbose=1,
    callbacks=callbacks_list)

    if print_model:
        model.summary()
        
    del model
    keras.backend.clear_session()
    return result

# %% [markdown]
# ### save model history

# %%
model_history = fine_tune_model(train_df, test_df,100,16,'beard')
# Out:
# W0831 21:26:32.131244 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 21:26:32.132208 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 21:26:32.134258 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0831 21:26:32.149200 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0831 21:26:32.761087 140037082343232 deprecation.py:506] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0831 21:26:32.853686 140037082343232 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0831 21:26:32.859359 140037082343232 deprecation.py:323] From /home/mindy/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Found 363 validated image filenames belonging to 2 classes.
# Found 91 validated image filenames belonging to 2 classes.
# Epoch 1/100
# 22/22 [==============================] - 4s 169ms/step - loss: 2.9213 - acc: 0.3606 - val_loss: 0.7761 - val_acc: 0.4375
#
# Epoch 00001: val_acc improved from -inf to 0.43750, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 2/100
# 22/22 [==============================] - 3s 148ms/step - loss: 0.8386 - acc: 0.5199 - val_loss: 0.7267 - val_acc: 0.4400
#
# Epoch 00002: val_acc improved from 0.43750 to 0.44000, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 3/100
# 22/22 [==============================] - 3s 141ms/step - loss: 0.7304 - acc: 0.5163 - val_loss: 0.6919 - val_acc: 0.5333
#
# Epoch 00003: val_acc improved from 0.44000 to 0.53333, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 4/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.6921 - acc: 0.5447 - val_loss: 0.6813 - val_acc: 0.5067
#
# Epoch 00004: val_acc did not improve from 0.53333
# Epoch 5/100
# 22/22 [==============================] - 3s 127ms/step - loss: 0.7079 - acc: 0.5065 - val_loss: 0.6891 - val_acc: 0.5200
#
# Epoch 00005: val_acc did not improve from 0.53333
# Epoch 6/100
# 22/22 [==============================] - 3s 122ms/step - loss: 0.7164 - acc: 0.4809 - val_loss: 0.6385 - val_acc: 0.7467
#
# Epoch 00006: val_acc improved from 0.53333 to 0.74667, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 7/100
# 22/22 [==============================] - 3s 135ms/step - loss: 0.6692 - acc: 0.6193 - val_loss: 0.6547 - val_acc: 0.6000
#
# Epoch 00007: val_acc did not improve from 0.74667
# Epoch 8/100
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6678 - acc: 0.5841 - val_loss: 0.6263 - val_acc: 0.7067
#
# Epoch 00008: val_acc did not improve from 0.74667
# Epoch 9/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.6362 - acc: 0.6450 - val_loss: 0.5711 - val_acc: 0.8133
#
# Epoch 00009: val_acc improved from 0.74667 to 0.81333, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 10/100
# 22/22 [==============================] - 3s 145ms/step - loss: 0.6116 - acc: 0.6751 - val_loss: 0.5687 - val_acc: 0.7867
#
# Epoch 00010: val_acc did not improve from 0.81333
# Epoch 11/100
# 22/22 [==============================] - 3s 119ms/step - loss: 0.6000 - acc: 0.7102 - val_loss: 0.5469 - val_acc: 0.8000
#
# Epoch 00011: val_acc did not improve from 0.81333
# Epoch 12/100
# 22/22 [==============================] - 3s 117ms/step - loss: 0.6230 - acc: 0.6691 - val_loss: 0.5607 - val_acc: 0.7200
#
# Epoch 00012: val_acc did not improve from 0.81333
# Epoch 13/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.5765 - acc: 0.6893 - val_loss: 0.4840 - val_acc: 0.8250
#
# Epoch 00013: val_acc improved from 0.81333 to 0.82500, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 14/100
# 22/22 [==============================] - 3s 153ms/step - loss: 0.5317 - acc: 0.7774 - val_loss: 0.4551 - val_acc: 0.8400
#
# Epoch 00014: val_acc improved from 0.82500 to 0.84000, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 15/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.5168 - acc: 0.7550 - val_loss: 0.4723 - val_acc: 0.8400
#
# Epoch 00015: val_acc did not improve from 0.84000
# Epoch 16/100
# 22/22 [==============================] - 3s 122ms/step - loss: 0.5025 - acc: 0.7642 - val_loss: 0.4512 - val_acc: 0.8000
#
# Epoch 00016: val_acc did not improve from 0.84000
# Epoch 17/100
# 22/22 [==============================] - 3s 139ms/step - loss: 0.4707 - acc: 0.7904 - val_loss: 0.4039 - val_acc: 0.8533
#
# Epoch 00017: val_acc improved from 0.84000 to 0.85333, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 18/100
# 22/22 [==============================] - 3s 120ms/step - loss: 0.4628 - acc: 0.7982 - val_loss: 0.3982 - val_acc: 0.8400
#
# Epoch 00018: val_acc did not improve from 0.85333
# Epoch 19/100
# 22/22 [==============================] - 3s 134ms/step - loss: 0.4621 - acc: 0.7819 - val_loss: 0.3587 - val_acc: 0.8125
#
# Epoch 00019: val_acc did not improve from 0.85333
# Epoch 20/100
# 22/22 [==============================] - 3s 142ms/step - loss: 0.4298 - acc: 0.7998 - val_loss: 0.4437 - val_acc: 0.8000
#
# Epoch 00020: val_acc did not improve from 0.85333
# Epoch 21/100
# 22/22 [==============================] - 3s 121ms/step - loss: 0.4121 - acc: 0.8412 - val_loss: 0.2287 - val_acc: 0.9467
#
# Epoch 00021: val_acc improved from 0.85333 to 0.94667, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 22/100
# 22/22 [==============================] - 3s 137ms/step - loss: 0.3834 - acc: 0.8554 - val_loss: 0.4303 - val_acc: 0.7600
#
# Epoch 00022: val_acc did not improve from 0.94667
# Epoch 23/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.3910 - acc: 0.7961 - val_loss: 0.3092 - val_acc: 0.8400
#
# Epoch 00023: val_acc did not improve from 0.94667
# Epoch 24/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.3845 - acc: 0.8327 - val_loss: 0.3550 - val_acc: 0.8400
#
# Epoch 00024: val_acc did not improve from 0.94667
# Epoch 25/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.4288 - acc: 0.8099 - val_loss: 0.3282 - val_acc: 0.8875
#
# Epoch 00025: val_acc did not improve from 0.94667
# Epoch 26/100
# 22/22 [==============================] - 3s 154ms/step - loss: 0.3530 - acc: 0.8428 - val_loss: 0.2540 - val_acc: 0.9067
#
# Epoch 00026: val_acc did not improve from 0.94667
# Epoch 27/100
# 22/22 [==============================] - 3s 130ms/step - loss: 0.3350 - acc: 0.8579 - val_loss: 0.2544 - val_acc: 0.9067
#
# Epoch 00027: val_acc did not improve from 0.94667
# Epoch 28/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.3164 - acc: 0.8665 - val_loss: 0.3203 - val_acc: 0.9067
#
# Epoch 00028: val_acc did not improve from 0.94667
# Epoch 29/100
# 22/22 [==============================] - 3s 119ms/step - loss: 0.2972 - acc: 0.8882 - val_loss: 0.2842 - val_acc: 0.8933
#
# Epoch 00029: val_acc did not improve from 0.94667
# Epoch 30/100
# 22/22 [==============================] - 3s 138ms/step - loss: 0.3420 - acc: 0.8472 - val_loss: 0.3233 - val_acc: 0.8533
#
# Epoch 00030: val_acc did not improve from 0.94667
# Epoch 31/100
# 22/22 [==============================] - 3s 124ms/step - loss: 0.3274 - acc: 0.8607 - val_loss: 0.2241 - val_acc: 0.9375
#
# Epoch 00031: val_acc did not improve from 0.94667
# Epoch 32/100
# 22/22 [==============================] - 3s 131ms/step - loss: 0.3294 - acc: 0.8580 - val_loss: 0.3158 - val_acc: 0.8667
#
# Epoch 00032: val_acc did not improve from 0.94667
# Epoch 33/100
# 22/22 [==============================] - 3s 138ms/step - loss: 0.3194 - acc: 0.8610 - val_loss: 0.3110 - val_acc: 0.8667
#
# Epoch 00033: val_acc did not improve from 0.94667
# Epoch 34/100
# 22/22 [==============================] - 3s 121ms/step - loss: 0.2991 - acc: 0.8778 - val_loss: 0.1909 - val_acc: 0.9600
#
# Epoch 00034: val_acc improved from 0.94667 to 0.96000, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 35/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.2472 - acc: 0.9050 - val_loss: 0.2851 - val_acc: 0.9200
#
# Epoch 00035: val_acc did not improve from 0.96000
# Epoch 36/100
# 22/22 [==============================] - 3s 126ms/step - loss: 0.2360 - acc: 0.9006 - val_loss: 0.3136 - val_acc: 0.9067
#
# Epoch 00036: val_acc did not improve from 0.96000
# Epoch 37/100
# 22/22 [==============================] - 3s 136ms/step - loss: 0.3179 - acc: 0.8528 - val_loss: 0.2757 - val_acc: 0.9250
#
# Epoch 00037: val_acc did not improve from 0.96000
# Epoch 38/100
# 22/22 [==============================] - 3s 149ms/step - loss: 0.2549 - acc: 0.8949 - val_loss: 0.1816 - val_acc: 0.9467
#
# Epoch 00038: val_acc did not improve from 0.96000
# Epoch 39/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.2476 - acc: 0.8936 - val_loss: 0.2781 - val_acc: 0.9333
#
# Epoch 00039: val_acc did not improve from 0.96000
# Epoch 40/100
# 22/22 [==============================] - 3s 127ms/step - loss: 0.2855 - acc: 0.8765 - val_loss: 0.1800 - val_acc: 0.9333
#
# Epoch 00040: val_acc did not improve from 0.96000
# Epoch 41/100
# 22/22 [==============================] - 3s 138ms/step - loss: 0.2167 - acc: 0.9391 - val_loss: 0.2958 - val_acc: 0.8933
#
# Epoch 00041: val_acc did not improve from 0.96000
# Epoch 42/100
# 22/22 [==============================] - 3s 122ms/step - loss: 0.2202 - acc: 0.9252 - val_loss: 0.2425 - val_acc: 0.9333
#
# Epoch 00042: val_acc did not improve from 0.96000
# Epoch 43/100
# 22/22 [==============================] - 3s 127ms/step - loss: 0.2034 - acc: 0.9403 - val_loss: 0.2626 - val_acc: 0.9125
#
# Epoch 00043: val_acc did not improve from 0.96000
# Epoch 44/100
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1950 - acc: 0.9176 - val_loss: 0.2228 - val_acc: 0.9333
#
# Epoch 00044: val_acc did not improve from 0.96000
# Epoch 45/100
# 22/22 [==============================] - 3s 133ms/step - loss: 0.2785 - acc: 0.8721 - val_loss: 0.2114 - val_acc: 0.9333
#
# Epoch 00045: val_acc did not improve from 0.96000
# Epoch 46/100
# 22/22 [==============================] - 3s 134ms/step - loss: 0.1791 - acc: 0.9403 - val_loss: 0.2344 - val_acc: 0.9200
#
# Epoch 00046: val_acc did not improve from 0.96000
# Epoch 47/100
# 22/22 [==============================] - 3s 124ms/step - loss: 0.2122 - acc: 0.9176 - val_loss: 0.2748 - val_acc: 0.8933
#
# Epoch 00047: val_acc did not improve from 0.96000
# Epoch 48/100
# 22/22 [==============================] - 3s 139ms/step - loss: 0.1827 - acc: 0.9403 - val_loss: 0.3108 - val_acc: 0.9067
#
# Epoch 00048: val_acc did not improve from 0.96000
# Epoch 49/100
# 22/22 [==============================] - 3s 127ms/step - loss: 0.2254 - acc: 0.8996 - val_loss: 0.2203 - val_acc: 0.9250
#
# Epoch 00049: val_acc did not improve from 0.96000
# Epoch 50/100
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1914 - acc: 0.9318 - val_loss: 0.0915 - val_acc: 0.9867
#
# Epoch 00050: val_acc improved from 0.96000 to 0.98667, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 51/100
# 22/22 [==============================] - 3s 133ms/step - loss: 0.1691 - acc: 0.9293 - val_loss: 0.3512 - val_acc: 0.8800
#
# Epoch 00051: val_acc did not improve from 0.98667
# Epoch 52/100
# 22/22 [==============================] - 3s 124ms/step - loss: 0.1875 - acc: 0.9163 - val_loss: 0.3079 - val_acc: 0.9200
#
# Epoch 00052: val_acc did not improve from 0.98667
# Epoch 53/100
# 22/22 [==============================] - 3s 131ms/step - loss: 0.2236 - acc: 0.9006 - val_loss: 0.2430 - val_acc: 0.9067
#
# Epoch 00053: val_acc did not improve from 0.98667
# Epoch 54/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.2125 - acc: 0.9192 - val_loss: 0.2244 - val_acc: 0.9467
#
# Epoch 00054: val_acc did not improve from 0.98667
# Epoch 55/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1367 - acc: 0.9391 - val_loss: 0.1516 - val_acc: 0.9375
#
# Epoch 00055: val_acc did not improve from 0.98667
# Epoch 56/100
# 22/22 [==============================] - 3s 153ms/step - loss: 0.1832 - acc: 0.9375 - val_loss: 0.3306 - val_acc: 0.9200
#
# Epoch 00056: val_acc did not improve from 0.98667
# Epoch 57/100
# 22/22 [==============================] - 3s 120ms/step - loss: 0.1991 - acc: 0.9248 - val_loss: 0.1927 - val_acc: 0.9467
#
# Epoch 00057: val_acc did not improve from 0.98667
# Epoch 58/100
# 22/22 [==============================] - 3s 124ms/step - loss: 0.1281 - acc: 0.9618 - val_loss: 0.2710 - val_acc: 0.8933
#
# Epoch 00058: val_acc did not improve from 0.98667
# Epoch 59/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1519 - acc: 0.9403 - val_loss: 0.2083 - val_acc: 0.9200
#
# Epoch 00059: val_acc did not improve from 0.98667
# Epoch 60/100
# 22/22 [==============================] - 3s 122ms/step - loss: 0.1411 - acc: 0.9504 - val_loss: 0.2115 - val_acc: 0.9200
#
# Epoch 00060: val_acc did not improve from 0.98667
# Epoch 61/100
# 22/22 [==============================] - 3s 133ms/step - loss: 0.1525 - acc: 0.9432 - val_loss: 0.2126 - val_acc: 0.9250
#
# Epoch 00061: val_acc did not improve from 0.98667
# Epoch 62/100
# 22/22 [==============================] - 3s 142ms/step - loss: 0.1397 - acc: 0.9378 - val_loss: 0.2783 - val_acc: 0.9200
#
# Epoch 00062: val_acc did not improve from 0.98667
# Epoch 63/100
# 22/22 [==============================] - 3s 137ms/step - loss: 0.1390 - acc: 0.9533 - val_loss: 0.3326 - val_acc: 0.9200
#
# Epoch 00063: val_acc did not improve from 0.98667
# Epoch 64/100
# 22/22 [==============================] - 3s 116ms/step - loss: 0.1366 - acc: 0.9460 - val_loss: 0.0787 - val_acc: 0.9867
#
# Epoch 00064: val_acc did not improve from 0.98667
# Epoch 65/100
# 22/22 [==============================] - 3s 137ms/step - loss: 0.1348 - acc: 0.9517 - val_loss: 0.3441 - val_acc: 0.9067
#
# Epoch 00065: val_acc did not improve from 0.98667
# Epoch 66/100
# 22/22 [==============================] - 3s 125ms/step - loss: 0.0967 - acc: 0.9647 - val_loss: 0.1740 - val_acc: 0.9467
#
# Epoch 00066: val_acc did not improve from 0.98667
# Epoch 67/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1702 - acc: 0.9375 - val_loss: 0.2461 - val_acc: 0.9250
#
# Epoch 00067: val_acc did not improve from 0.98667
# Epoch 68/100
# 22/22 [==============================] - 3s 139ms/step - loss: 0.1248 - acc: 0.9602 - val_loss: 0.1642 - val_acc: 0.9600
#
# Epoch 00068: val_acc did not improve from 0.98667
# Epoch 69/100
# 22/22 [==============================] - 3s 125ms/step - loss: 0.1356 - acc: 0.9574 - val_loss: 0.3033 - val_acc: 0.9200
#
# Epoch 00069: val_acc did not improve from 0.98667
# Epoch 70/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.1895 - acc: 0.9135 - val_loss: 0.1395 - val_acc: 0.9467
#
# Epoch 00070: val_acc did not improve from 0.98667
# Epoch 71/100
# 22/22 [==============================] - 3s 137ms/step - loss: 0.0933 - acc: 0.9789 - val_loss: 0.3478 - val_acc: 0.8933
#
# Epoch 00071: val_acc did not improve from 0.98667
# Epoch 72/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.1403 - acc: 0.9403 - val_loss: 0.1807 - val_acc: 0.9733
#
# Epoch 00072: val_acc did not improve from 0.98667
# Epoch 73/100
# 22/22 [==============================] - 3s 133ms/step - loss: 0.1616 - acc: 0.9318 - val_loss: 0.1861 - val_acc: 0.9250
#
# Epoch 00073: val_acc did not improve from 0.98667
# Epoch 74/100
# 22/22 [==============================] - 3s 145ms/step - loss: 0.1433 - acc: 0.9489 - val_loss: 0.2372 - val_acc: 0.9200
#
# Epoch 00074: val_acc did not improve from 0.98667
# Epoch 75/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1073 - acc: 0.9561 - val_loss: 0.1733 - val_acc: 0.9467
#
# Epoch 00075: val_acc did not improve from 0.98667
# Epoch 76/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1029 - acc: 0.9675 - val_loss: 0.2341 - val_acc: 0.9467
#
# Epoch 00076: val_acc did not improve from 0.98667
# Epoch 77/100
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0870 - acc: 0.9630 - val_loss: 0.2364 - val_acc: 0.9333
#
# Epoch 00077: val_acc did not improve from 0.98667
# Epoch 78/100
# 22/22 [==============================] - 3s 127ms/step - loss: 0.0995 - acc: 0.9716 - val_loss: 0.1913 - val_acc: 0.9467
#
# Epoch 00078: val_acc did not improve from 0.98667
# Epoch 79/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.1006 - acc: 0.9574 - val_loss: 0.1944 - val_acc: 0.9375
#
# Epoch 00079: val_acc did not improve from 0.98667
# Epoch 80/100
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1317 - acc: 0.9504 - val_loss: 0.2907 - val_acc: 0.8933
#
# Epoch 00080: val_acc did not improve from 0.98667
# Epoch 81/100
# 22/22 [==============================] - 3s 133ms/step - loss: 0.1051 - acc: 0.9659 - val_loss: 0.1512 - val_acc: 0.9600
#
# Epoch 00081: val_acc did not improve from 0.98667
# Epoch 82/100
# 22/22 [==============================] - 3s 135ms/step - loss: 0.1048 - acc: 0.9545 - val_loss: 0.3066 - val_acc: 0.9333
#
# Epoch 00082: val_acc did not improve from 0.98667
# Epoch 83/100
# 22/22 [==============================] - 3s 117ms/step - loss: 0.1148 - acc: 0.9533 - val_loss: 0.1633 - val_acc: 0.9467
#
# Epoch 00083: val_acc did not improve from 0.98667
# Epoch 84/100
# 22/22 [==============================] - 3s 128ms/step - loss: 0.1052 - acc: 0.9573 - val_loss: 0.1749 - val_acc: 0.9600
#
# Epoch 00084: val_acc did not improve from 0.98667
# Epoch 85/100
# 22/22 [==============================] - 3s 147ms/step - loss: 0.1346 - acc: 0.9432 - val_loss: 0.3019 - val_acc: 0.9125
#
# Epoch 00085: val_acc did not improve from 0.98667
# Epoch 86/100
# 22/22 [==============================] - 3s 144ms/step - loss: 0.0864 - acc: 0.9732 - val_loss: 0.2347 - val_acc: 0.8933
#
# Epoch 00086: val_acc did not improve from 0.98667
# Epoch 87/100
# 22/22 [==============================] - 3s 121ms/step - loss: 0.0838 - acc: 0.9687 - val_loss: 0.2087 - val_acc: 0.9333
#
# Epoch 00087: val_acc did not improve from 0.98667
# Epoch 88/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.1061 - acc: 0.9561 - val_loss: 0.2344 - val_acc: 0.9333
#
# Epoch 00088: val_acc did not improve from 0.98667
# Epoch 89/100
# 22/22 [==============================] - 3s 131ms/step - loss: 0.0678 - acc: 0.9773 - val_loss: 0.2581 - val_acc: 0.9467
#
# Epoch 00089: val_acc did not improve from 0.98667
# Epoch 90/100
# 22/22 [==============================] - 3s 124ms/step - loss: 0.0880 - acc: 0.9687 - val_loss: 0.1527 - val_acc: 0.9600
#
# Epoch 00090: val_acc did not improve from 0.98667
# Epoch 91/100
# 22/22 [==============================] - 3s 134ms/step - loss: 0.1342 - acc: 0.9432 - val_loss: 0.2374 - val_acc: 0.9250
#
# Epoch 00091: val_acc did not improve from 0.98667
# Epoch 92/100
# 22/22 [==============================] - 3s 153ms/step - loss: 0.1679 - acc: 0.9249 - val_loss: 0.2215 - val_acc: 0.9200
#
# Epoch 00092: val_acc did not improve from 0.98667
# Epoch 93/100
# 22/22 [==============================] - 3s 123ms/step - loss: 0.0722 - acc: 0.9801 - val_loss: 0.0688 - val_acc: 0.9733
#
# Epoch 00093: val_acc did not improve from 0.98667
# Epoch 94/100
# 22/22 [==============================] - 3s 141ms/step - loss: 0.0857 - acc: 0.9716 - val_loss: 0.2892 - val_acc: 0.9200
#
# Epoch 00094: val_acc did not improve from 0.98667
# Epoch 95/100
# 22/22 [==============================] - 3s 135ms/step - loss: 0.1141 - acc: 0.9561 - val_loss: 0.1678 - val_acc: 0.9467
#
# Epoch 00095: val_acc did not improve from 0.98667
# Epoch 96/100
# 22/22 [==============================] - 3s 126ms/step - loss: 0.1056 - acc: 0.9716 - val_loss: 0.2342 - val_acc: 0.9200
#
# Epoch 00096: val_acc did not improve from 0.98667
# Epoch 97/100
# 22/22 [==============================] - 3s 135ms/step - loss: 0.0883 - acc: 0.9659 - val_loss: 0.1498 - val_acc: 0.9500
#
# Epoch 00097: val_acc did not improve from 0.98667
# Epoch 98/100
# 22/22 [==============================] - 3s 139ms/step - loss: 0.0831 - acc: 0.9602 - val_loss: 0.2658 - val_acc: 0.8933
#
# Epoch 00098: val_acc did not improve from 0.98667
# Epoch 99/100
# 22/22 [==============================] - 3s 129ms/step - loss: 0.0579 - acc: 0.9915 - val_loss: 0.0474 - val_acc: 0.9867
#
# Epoch 00099: val_acc improved from 0.98667 to 0.98667, saving model to ../tuning_data/best_vgg_model_beard_2.h5
# Epoch 100/100
# 22/22 [==============================] - 3s 132ms/step - loss: 0.0561 - acc: 0.9858 - val_loss: 0.3378 - val_acc: 0.9067
#
# Epoch 00100: val_acc did not improve from 0.98667
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 2097665
# =================================================================
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
highest_val_acc, highest_train_acc = max(model_history.history['val_acc']), max(model_history.history['acc'])
print(f'highest test accuracy: {highest_val_acc}')
print('------------------')
print(f'highest train accuracy: {highest_train_acc}')
# Out:
# highest test accuracy: 0.9866666706403097
# ------------------
# highest train accuracy: 0.9913544668587896

# %%
lowest_val_loss, lowest_train_loss = min(model_history.history['val_loss']), min(model_history.history['loss'])
print(f'lowest test loss: {lowest_val_loss}')
print('------------------')
print(f'lowest train loss: {lowest_train_loss}')
# Out:
# lowest test loss: 0.047419183651606245
# ------------------
# lowest train loss: 0.05610874659297141

# %%
plt.plot(model_history.history['val_acc'], color = 'red', label = 'test')
plt.plot(model_history.history['acc'], color = 'blue', label = 'train')
plt.title('accuracy')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
plt.plot(model_history.history['val_loss'], color = 'red', label = 'test')
plt.plot(model_history.history['loss'], color = 'blue', label = 'train')
plt.title('loss')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Save model

# %%
# save model artchitecture 
beard_model = model_history.model
beard_model_json = beard_model.to_json()

# %%
# serialize model to JSON
with open("beard_model.json", "w") as json_file:
    json_file.write(beard_model_json)

# %%
# load json and create model
json_file = open('../tuning_data/vgg_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_beard = model_from_json(loaded_model_json)
# Out:
# W0829 21:20:55.576644 139978373949248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0829 21:20:55.586904 139978373949248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0829 21:20:55.593295 139978373949248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0829 21:20:55.596627 139978373949248 deprecation.py:506] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0829 21:20:55.620089 139978373949248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# load model weight 
loaded_model_beard.load_weights('../tuning_data/best_vgg_model_beard.h5')

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator =  test_gen.flow_from_dataframe(
    dataframe=test_df,
    directory='../data/pics',
    x_col='pic_id',
    y_col='beard',
    batch_size=16,
    target_size=(150,150),
    class_mode = 'binary')
# Out:
# Found 91 validated image filenames belonging to 2 classes.

# %%
loaded_model_beard.compile(loss='binary_crossentropy',
             optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
             metrics=['accuracy'])
# Out:
# W0829 21:21:04.399917 139978373949248 deprecation_wrapper.py:119] From /home/mindy/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0829 21:21:04.404289 139978373949248 deprecation.py:323] From /home/mindy/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
loaded_model_beard.evaluate_generator(test_generator)
# Out:
# [0.16778260303640757, 0.945054945054945]

# %%
feature, label = next(test_generator)

# %%
label[1]
# Out:
# 0.0

# %%
plt.imshow(feature[1])
plt.show()

# %%
# save the model
np.around(loaded_model_beard.predict(np.expand_dims(feature[1], axis=0)))
# Out:
# array([[0.]], dtype=float32)
